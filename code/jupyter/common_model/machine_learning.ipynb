# %% [markdown]
# # Machine Learning Algorithm

# %% [markdown]
# ## 决策树 Decision Tree

# %% [markdown]
# # 随机森林 Random Forest
# 本质上是DT+自举聚合(bagging)的产物，用多棵树进行训练，最后根据这些树的结果来输出，类似集思广益

# %% [markdown]
# ## 各种GBDT(gadient boost decision tree)
# 本质上是DT+集成学习(boost)的产物，用下一课树来拟合之前所有树之和与真实值的差，区别在于算法不同。利用boost算法可以将多个弱学习器提升成强学习器，可以有效提高精度
# - LightGBM
# - XGBoost

# %% [markdown]
# ## 最临近算法KNN
