# %%
import numpy as np


class Variable:
    def __init__(self, data):
        if data is not None:
            if not isinstance(data, np.ndarray):
                raise TypeError('{} is not supported'.format(type(data)))

        self.data = data
        self.grad = None
        self.creator = None
        self.generation = 0

    def set_creator(self, f):
        self.creator = f
        self.generation = f.generation + 1

    def backward(self):
        if self.grad is None:
            self.grad = np.ones_like(self.data)
        funcs = []
        funcs.append(self.creator)
        seen_set = set()
        def add_func(f):
            if f not in seen_set:
                funcs.append(f)
                seen_set.add(f)
                funcs.sort(key=lambda x: x.generation)
        #add_func(self.creator)
        while funcs:
            f = funcs.pop()
            # ys = f.outputs
            gys = [y.grad for y in f.outputs]
            # xs = f.inputs
            # x.grad = f.backward(y.grad)
            gxs = f.backward(*gys)
            for x, gx in zip(f.inputs, gxs):
                if x.grad:
                    x.grad = x.grad + gx
                else:
                    x.grad = gx
                if x.creator is not None:
                    funcs.append(self.creator)
    def cleargrad(self):
        self.grad = None
class Function:
    def __call__(self, *inputs):
        # x = input.data # unzip
        xs = [input.data for input in inputs]
        ys = self.forward(*xs)
        if not isinstance(ys, tuple):
            ys = (ys,)
        outputs = [Variable(as_array(y)) for y in ys]
        self.inputs = inputs
        self.outputs = outputs
        self.generation = np.max([input.generation for input in inputs])
        for output in outputs:
            output.set_creator(self)
        return outputs if len(outputs) > 1 else outputs[0]

    def forward(self, x):
        raise NotImplementedError

    def backward(self, gy):
        raise NotImplementedError


def as_array(x):
    if np.isscalar(x):
        return np.array(x)
    return x


class Square(Function):
    def forward(self, x):
        return x ** 2

    def backward(self, gy):
        x = self.inputs[0].data
        gx = 2 * x * gy
        return gx


class Exp(Function):
    def forward(self, x):
        return np.exp(x)

    def backward(self, gy):
        x = self.inputs[0].data
        gx = np.exp(x) * gy
        return gx


class Add(Function):
    def forward(self, x0, x1):
        y = x0 + x1
        return y

    def backward(self, gy):
        return gy, gy


def exp(x):
    return Exp()(x)


def square(x):
    return Square()(x)

def add(x0, x1):
    return Add()(x0,x1)

# %%
x = Variable(np.array(2.0))
a = square(x)
y = add(square(a), square(a))
y.backward()
print(y.data)
print(x.grad)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 4
#       2 a = square(x)
#       3 y = add(square(a), square(a))
# ----> 4 y.backward()
#       5 print(y.data)
#       6 print(x.grad)
#
# Cell In[40], line 37, in Variable.backward(self)
#      34 gys = [y.grad for y in f.outputs]
#      35 # xs = f.inputs
#      36 # x.grad = f.backward(y.grad)
# ---> 37 gxs = f.backward(*gys)
#      38 for x, gx in zip(f.inputs, gxs):
#      39     if x.grad:
#
# KeyboardInterrupt:

# %%
x = Variable(np.array([0.5]))
y = Variable(np.array([21.5]))
f = Add()
z = f(x,y)
print(z.data)
# Out:
# [22.]

# %%
A = Square()
B = Exp()
C = Square()

x = Variable(np.array([0.5,1,1.5,2]))
a = A(x)
print(a.creator)
b = B(a)
print(b.creator)
y = C(b)
print(y.creator)

y.backward()
print(y.grad)
print(b.grad)
print(a.grad)
print(x.grad)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 13
#      10 y = C(b)
#      11 print(y.creator)
# ---> 13 y.backward()
#      14 print(y.grad)
#      15 print(b.grad)
#
# Cell In[1], line 23, in Variable.backward(self)
#      20 gys = [y.grad for y in f.outputs]
#      21 #xs = f.inputs
#      22 #x.grad = f.backward(y.grad)
# ---> 23 gxs = f.backward(*gys)
#      24 for x,gx in zip(f.inputs, gxs):
#      25     x.grad = gx
#
# Cell In[1], line 54, in Square.backward(self, gy)
#      53 def backward(self, gy):
# ---> 54     x = self.inputs.data
#      55     gx = 2 * x * gy
#      56     return gx
#
# AttributeError: 'tuple' object has no attribute 'data'

# %%
np.exp(0.25) *2 * np.exp(0.25)
# Out:
# np.float64(3.297442541400256)

# %%
def numerical_diff(f, x, eps=1e-3):
    x0, x1 = Variable(x.data - eps), Variable(x.data + eps)
    y0, y1 = f(x0), f(x1)
    return (y1.data - y0.data) / ( 2 * eps)

# %%
x = Variable(np.array([0]))
f = Square()
numerical_diff(f, x, eps=10)
# Out:
# array([0.])
